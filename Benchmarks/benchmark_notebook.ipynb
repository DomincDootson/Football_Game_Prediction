# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn import model_selection
from sklearn.metrics import accuracy_score
import xgboost as xgb
import warnings
import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read Train data

# %%
# train_home_team_statistics_df = pd.read_csv('train_home_team_statistics_df.csv', index_col=0)
# train_away_team_statistics_df = pd.read_csv('train_away_team_statistics_df.csv', index_col=0)

# train_scores = pd.read_csv('Y_train.csv', index_col=0)

# train_home = train_home_team_statistics_df.iloc[:,2:]
# train_away = train_away_team_statistics_df.iloc[:,2:]

# train_home.columns = 'HOME_' + train_home.columns
# train_away.columns = 'AWAY_' + train_away.columns

# train_data =  pd.concat([train_home,train_away],join='inner',axis=1)

# train_scores = train_scores.loc[train_data.index]

# train_data = train_data.replace({np.inf:np.nan,-np.inf:np.nan})

# %%
train_data = pd.read_csv("Benchmark_dataset.csv")
train_scores = pd.read_csv('Y_train.csv', index_col=0)
train_scores = train_scores.loc[train_data.index]

# %%
# train_home_team_statistics_df.head()
# Out:
#             LEAGUE                TEAM_NAME  TEAM_SHOTS_TOTAL_season_sum  \
# ID
# 0          Ligue 1                 Toulouse                          3.0
# 1          Ligue 2                    Brest                          6.0
# 2          Serie A                Sampdoria                          4.0
# 3       League One            Coventry City                          7.0
# 4   Premier League  Wolverhampton Wanderers                          3.0
#
#     TEAM_SHOTS_INSIDEBOX_season_sum  TEAM_SHOTS_OFF_TARGET_season_sum  \
# ID
# 0                               2.0                               5.0
# 1                               8.0                               3.0
# 2                               2.0                               5.0
# 3                               5.0                               5.0
# 4                               3.0                               2.0
#
#     TEAM_SHOTS_ON_TARGET_season_sum  TEAM_SHOTS_OUTSIDEBOX_season_sum  \
# ID
# 0                               2.0                               1.0
# 1                               6.0                               5.0
# 2                               2.0                               8.0
# 3                               6.0                               6.0
# 4                               3.0                               4.0
#
#     TEAM_PASSES_season_sum  TEAM_SUCCESSFUL_PASSES_season_sum  \
# ID
# 0                      2.0                                2.0
# 1                      8.0                                7.0
# 2                      1.0                                1.0
# 3                      9.0                                9.0
# 4                      4.0                                3.0
#
#     TEAM_SAVES_season_sum  ...  TEAM_YELLOWCARDS_5_last_match_std  \
# ID                         ...
# 0                     5.0  ...                                3.0
# 1                    10.0  ...                                4.0
# 2                     2.0  ...                                4.0
# 3                     2.0  ...                                4.0
# 4                     4.0  ...                                1.0
#
#     TEAM_REDCARDS_5_last_match_std  TEAM_OFFSIDES_5_last_match_std  \
# ID
# 0                              0.0                             6.0
# 1                              0.0                             4.0
# 2                              5.0                             6.0
# 3                              0.0                             1.0
# 4                              0.0                             2.0
#
#     TEAM_ATTACKS_5_last_match_std  TEAM_PENALTIES_5_last_match_std  \
# ID
# 0                             0.0                             10.0
# 1                             3.0                             10.0
# 2                             3.0                              6.0
# 3                             8.0                              8.0
# 4                             5.0                              8.0
#
#     TEAM_SUBSTITUTIONS_5_last_match_std  TEAM_BALL_SAFE_5_last_match_std  \
# ID
# 0                                   8.0                              7.0
# 1                                   0.0                              1.0
# 2                                   7.0                              2.0
# 3                                   5.0                              5.0
# 4                                   7.0                              2.0
#
#     TEAM_DANGEROUS_ATTACKS_5_last_match_std  TEAM_INJURIES_5_last_match_std  \
# ID
# 0                                       2.0                             4.0
# 1                                       2.0                             8.0
# 2                                       3.0                             2.0
# 3                                       5.0                             NaN
# 4                                       6.0                             4.0
#
#     TEAM_GOALS_5_last_match_std
# ID
# 0                           3.0
# 1                           4.0
# 2                           4.0
# 3                           6.0
# 4                           4.0
#
# [5 rows x 142 columns]

# %%
# We want to save the data that this has read in
train_data.to_csv("Benchmark_dataset.csv")

# %%
train_scores.head()
# Out:
#    HOME_WINS  DRAW  AWAY_WINS
# 0          0     0          1
# 1          0     1          0
# 2          0     0          1
# 3          1     0          0
# 4          0     1          0

# %% [markdown]
# ## Benchmark
#
# We try to model if AWAY wins

# %%
train_new_y = train_scores['AWAY_WINS']

# %% [markdown]
# ### train, valid test split

# %%
X_train, X_test, y_train, y_test = model_selection.train_test_split(train_data, train_new_y, train_size=0.8, random_state=42)
X_train, X_valid, y_train, y_valid = model_selection.train_test_split(X_train, y_train, train_size=0.8, random_state=42)

# %% [markdown]
# ### xgb model

# %%
params_1 = {
    'booster': 'gbtree',
    'tree_method':'hist',
    'max_depth': 8, 
    'learning_rate': 0.025,
    'objective': 'multi:softprob',
    'num_class': 2,
    'eval_metric':'mlogloss'
    }


d_train = xgb.DMatrix(X_train.replace({0:np.nan}), y_train)
d_valid = xgb.DMatrix(X_valid.replace({0:np.nan}), y_valid)

num_round = 10000
evallist = [(d_train, 'train'), (d_valid, 'eval')]

bst = xgb.train(params_1, d_train, num_round, evallist, early_stopping_rounds=100)
# Out:
# [0]	train-mlogloss:0.68339	eval-mlogloss:0.68792
# [1]	train-mlogloss:0.67390	eval-mlogloss:0.68276
# [2]	train-mlogloss:0.66456	eval-mlogloss:0.67779
# [3]	train-mlogloss:0.65570	eval-mlogloss:0.67325
# [4]	train-mlogloss:0.64719	eval-mlogloss:0.66885
# [5]	train-mlogloss:0.63890	eval-mlogloss:0.66470
# [6]	train-mlogloss:0.63036	eval-mlogloss:0.66071
# [7]	train-mlogloss:0.62219	eval-mlogloss:0.65721
# [8]	train-mlogloss:0.61472	eval-mlogloss:0.65356
# [9]	train-mlogloss:0.60716	eval-mlogloss:0.65021
# [10]	train-mlogloss:0.59951	eval-mlogloss:0.64682
# [11]	train-mlogloss:0.59227	eval-mlogloss:0.64400
# [12]	train-mlogloss:0.58530	eval-mlogloss:0.64148
# [13]	train-mlogloss:0.57848	eval-mlogloss:0.63834
# [14]	train-mlogloss:0.57182	eval-mlogloss:0.63522
# [15]	train-mlogloss:0.56507	eval-mlogloss:0.63258
# [16]	train-mlogloss:0.55887	eval-mlogloss:0.62966
# [17]	train-mlogloss:0.55253	eval-mlogloss:0.62713
# [18]	train-mlogloss:0.54637	eval-mlogloss:0.62475
# [19]	train-mlogloss:0.54037	eval-mlogloss:0.62247
# [20]	train-mlogloss:0.53449	eval-mlogloss:0.62014
# [21]	train-mlogloss:0.52885	eval-mlogloss:0.61836
# [22]	train-mlogloss:0.52343	eval-mlogloss:0.61642
# [23]	train-mlogloss:0.51800	eval-mlogloss:0.61462
# [24]	train-mlogloss:0.51257	eval-mlogloss:0.61279
# [25]	train-mlogloss:0.50751	eval-mlogloss:0.61099
# [26]	train-mlogloss:0.50222	eval-mlogloss:0.60909
# [27]	train-mlogloss:0.49740	eval-mlogloss:0.60738
# [28]	train-mlogloss:0.49264	eval-mlogloss:0.60563
# [29]	train-mlogloss:0.48761	eval-mlogloss:0.60344
# [30]	train-mlogloss:0.48291	eval-mlogloss:0.60191
# [31]	train-mlogloss:0.47825	eval-mlogloss:0.60033
# [32]	train-mlogloss:0.47383	eval-mlogloss:0.59920
# [33]	train-mlogloss:0.46954	eval-mlogloss:0.59776
# [34]	train-mlogloss:0.46532	eval-mlogloss:0.59671
# [35]	train-mlogloss:0.46116	eval-mlogloss:0.59543
# [36]	train-mlogloss:0.45701	eval-mlogloss:0.59434
# [37]	train-mlogloss:0.45300	eval-mlogloss:0.59361
# [38]	train-mlogloss:0.44895	eval-mlogloss:0.59247
# [39]	train-mlogloss:0.44490	eval-mlogloss:0.59160
# [40]	train-mlogloss:0.44063	eval-mlogloss:0.59063
# [41]	train-mlogloss:0.43662	eval-mlogloss:0.58976
# [42]	train-mlogloss:0.43300	eval-mlogloss:0.58867
# [43]	train-mlogloss:0.42914	eval-mlogloss:0.58807
# [44]	train-mlogloss:0.42509	eval-mlogloss:0.58734
# [45]	train-mlogloss:0.42159	eval-mlogloss:0.58654
# [46]	train-mlogloss:0.41826	eval-mlogloss:0.58612
# [47]	train-mlogloss:0.41452	eval-mlogloss:0.58558
# [48]	train-mlogloss:0.41108	eval-mlogloss:0.58487
# [49]	train-mlogloss:0.40752	eval-mlogloss:0.58443
# [50]	train-mlogloss:0.40417	eval-mlogloss:0.58387
# [51]	train-mlogloss:0.40104	eval-mlogloss:0.58340
# [52]	train-mlogloss:0.39795	eval-mlogloss:0.58292
# [53]	train-mlogloss:0.39501	eval-mlogloss:0.58278
# [54]	train-mlogloss:0.39212	eval-mlogloss:0.58233
# [55]	train-mlogloss:0.38867	eval-mlogloss:0.58206
# [56]	train-mlogloss:0.38579	eval-mlogloss:0.58148
# [57]	train-mlogloss:0.38272	eval-mlogloss:0.58116
# [58]	train-mlogloss:0.37954	eval-mlogloss:0.58080
# [59]	train-mlogloss:0.37645	eval-mlogloss:0.58048
# [60]	train-mlogloss:0.37361	eval-mlogloss:0.58025
# [61]	train-mlogloss:0.37110	eval-mlogloss:0.57991
# [62]	train-mlogloss:0.36861	eval-mlogloss:0.57967
# [63]	train-mlogloss:0.36600	eval-mlogloss:0.57934
# [64]	train-mlogloss:0.36352	eval-mlogloss:0.57896
# [65]	train-mlogloss:0.36058	eval-mlogloss:0.57877
# [66]	train-mlogloss:0.35829	eval-mlogloss:0.57848
# [67]	train-mlogloss:0.35524	eval-mlogloss:0.57774
# [68]	train-mlogloss:0.35280	eval-mlogloss:0.57749
# [69]	train-mlogloss:0.35051	eval-mlogloss:0.57722
# [70]	train-mlogloss:0.34825	eval-mlogloss:0.57694
# [71]	train-mlogloss:0.34574	eval-mlogloss:0.57662
# [72]	train-mlogloss:0.34351	eval-mlogloss:0.57640
# [73]	train-mlogloss:0.34123	eval-mlogloss:0.57629
# [74]	train-mlogloss:0.33912	eval-mlogloss:0.57571
# [75]	train-mlogloss:0.33632	eval-mlogloss:0.57550
# [76]	train-mlogloss:0.33413	eval-mlogloss:0.57531
# [77]	train-mlogloss:0.33200	eval-mlogloss:0.57496
# [78]	train-mlogloss:0.32921	eval-mlogloss:0.57490
# [79]	train-mlogloss:0.32708	eval-mlogloss:0.57468
# [80]	train-mlogloss:0.32518	eval-mlogloss:0.57470
# [81]	train-mlogloss:0.32312	eval-mlogloss:0.57423
# [82]	train-mlogloss:0.32117	eval-mlogloss:0.57442
# [83]	train-mlogloss:0.31896	eval-mlogloss:0.57418
# [84]	train-mlogloss:0.31681	eval-mlogloss:0.57408
# [85]	train-mlogloss:0.31433	eval-mlogloss:0.57383
# [86]	train-mlogloss:0.31238	eval-mlogloss:0.57378
# [87]	train-mlogloss:0.31051	eval-mlogloss:0.57366
# [88]	train-mlogloss:0.30837	eval-mlogloss:0.57337
# [89]	train-mlogloss:0.30638	eval-mlogloss:0.57327
# [90]	train-mlogloss:0.30436	eval-mlogloss:0.57314
# [91]	train-mlogloss:0.30257	eval-mlogloss:0.57277
# [92]	train-mlogloss:0.30027	eval-mlogloss:0.57269
# [93]	train-mlogloss:0.29825	eval-mlogloss:0.57248
# [94]	train-mlogloss:0.29652	eval-mlogloss:0.57245
# [95]	train-mlogloss:0.29476	eval-mlogloss:0.57230
# [96]	train-mlogloss:0.29313	eval-mlogloss:0.57224
# [97]	train-mlogloss:0.29092	eval-mlogloss:0.57219
# [98]	train-mlogloss:0.28905	eval-mlogloss:0.57209
# [99]	train-mlogloss:0.28748	eval-mlogloss:0.57209
# [100]	train-mlogloss:0.28525	eval-mlogloss:0.57194
# [101]	train-mlogloss:0.28374	eval-mlogloss:0.57186
# [102]	train-mlogloss:0.28179	eval-mlogloss:0.57166
# [103]	train-mlogloss:0.28019	eval-mlogloss:0.57160
# [104]	train-mlogloss:0.27803	eval-mlogloss:0.57184
# [105]	train-mlogloss:0.27601	eval-mlogloss:0.57182
# [106]	train-mlogloss:0.27456	eval-mlogloss:0.57194
# [107]	train-mlogloss:0.27279	eval-mlogloss:0.57167
# [108]	train-mlogloss:0.27118	eval-mlogloss:0.57159
# [109]	train-mlogloss:0.26947	eval-mlogloss:0.57160
# [110]	train-mlogloss:0.26797	eval-mlogloss:0.57148
# [111]	train-mlogloss:0.26644	eval-mlogloss:0.57153
# [112]	train-mlogloss:0.26493	eval-mlogloss:0.57151
# [113]	train-mlogloss:0.26336	eval-mlogloss:0.57157
# [114]	train-mlogloss:0.26149	eval-mlogloss:0.57134
# [115]	train-mlogloss:0.26018	eval-mlogloss:0.57133
# [116]	train-mlogloss:0.25865	eval-mlogloss:0.57135
# [117]	train-mlogloss:0.25694	eval-mlogloss:0.57114
# [118]	train-mlogloss:0.25535	eval-mlogloss:0.57098
# [119]	train-mlogloss:0.25359	eval-mlogloss:0.57081
# [120]	train-mlogloss:0.25222	eval-mlogloss:0.57102
# [121]	train-mlogloss:0.25071	eval-mlogloss:0.57118
# [122]	train-mlogloss:0.24955	eval-mlogloss:0.57124
# [123]	train-mlogloss:0.24808	eval-mlogloss:0.57122
# [124]	train-mlogloss:0.24665	eval-mlogloss:0.57135
# [125]	train-mlogloss:0.24515	eval-mlogloss:0.57140
# [126]	train-mlogloss:0.24359	eval-mlogloss:0.57135
# [127]	train-mlogloss:0.24243	eval-mlogloss:0.57136
# [128]	train-mlogloss:0.24097	eval-mlogloss:0.57120
# [129]	train-mlogloss:0.23953	eval-mlogloss:0.57113
# [130]	train-mlogloss:0.23834	eval-mlogloss:0.57103
# [131]	train-mlogloss:0.23709	eval-mlogloss:0.57122
# [132]	train-mlogloss:0.23569	eval-mlogloss:0.57111
# [133]	train-mlogloss:0.23463	eval-mlogloss:0.57111
# [134]	train-mlogloss:0.23279	eval-mlogloss:0.57106
# [135]	train-mlogloss:0.23172	eval-mlogloss:0.57083
# [136]	train-mlogloss:0.23031	eval-mlogloss:0.57063
# [137]	train-mlogloss:0.22885	eval-mlogloss:0.57087
# [138]	train-mlogloss:0.22767	eval-mlogloss:0.57109
# [139]	train-mlogloss:0.22652	eval-mlogloss:0.57104
# [140]	train-mlogloss:0.22515	eval-mlogloss:0.57122
# [141]	train-mlogloss:0.22380	eval-mlogloss:0.57137
# [142]	train-mlogloss:0.22275	eval-mlogloss:0.57128
# [143]	train-mlogloss:0.22146	eval-mlogloss:0.57123
# [144]	train-mlogloss:0.22032	eval-mlogloss:0.57134
# [145]	train-mlogloss:0.21909	eval-mlogloss:0.57137
# [146]	train-mlogloss:0.21811	eval-mlogloss:0.57158
# [147]	train-mlogloss:0.21665	eval-mlogloss:0.57165
# [148]	train-mlogloss:0.21559	eval-mlogloss:0.57187
# [149]	train-mlogloss:0.21433	eval-mlogloss:0.57189
# [150]	train-mlogloss:0.21332	eval-mlogloss:0.57195
# [151]	train-mlogloss:0.21232	eval-mlogloss:0.57197
# [152]	train-mlogloss:0.21086	eval-mlogloss:0.57220
# [153]	train-mlogloss:0.20952	eval-mlogloss:0.57229
# [154]	train-mlogloss:0.20825	eval-mlogloss:0.57227
# [155]	train-mlogloss:0.20735	eval-mlogloss:0.57220
# [156]	train-mlogloss:0.20625	eval-mlogloss:0.57223
# [157]	train-mlogloss:0.20479	eval-mlogloss:0.57244
# [158]	train-mlogloss:0.20400	eval-mlogloss:0.57245
# [159]	train-mlogloss:0.20306	eval-mlogloss:0.57239
# [160]	train-mlogloss:0.20186	eval-mlogloss:0.57231
# [161]	train-mlogloss:0.20080	eval-mlogloss:0.57219
# [162]	train-mlogloss:0.19956	eval-mlogloss:0.57222
# [163]	train-mlogloss:0.19826	eval-mlogloss:0.57228
# [164]	train-mlogloss:0.19711	eval-mlogloss:0.57249
# [165]	train-mlogloss:0.19607	eval-mlogloss:0.57241
# [166]	train-mlogloss:0.19521	eval-mlogloss:0.57228
# [167]	train-mlogloss:0.19382	eval-mlogloss:0.57217
# [168]	train-mlogloss:0.19272	eval-mlogloss:0.57207
# [169]	train-mlogloss:0.19123	eval-mlogloss:0.57234
# [170]	train-mlogloss:0.19015	eval-mlogloss:0.57235
# [171]	train-mlogloss:0.18921	eval-mlogloss:0.57224
# [172]	train-mlogloss:0.18841	eval-mlogloss:0.57239
# [173]	train-mlogloss:0.18745	eval-mlogloss:0.57235
# [174]	train-mlogloss:0.18628	eval-mlogloss:0.57232
# [175]	train-mlogloss:0.18512	eval-mlogloss:0.57237
# [176]	train-mlogloss:0.18413	eval-mlogloss:0.57254
# [177]	train-mlogloss:0.18295	eval-mlogloss:0.57286
# [178]	train-mlogloss:0.18207	eval-mlogloss:0.57285
# [179]	train-mlogloss:0.18131	eval-mlogloss:0.57319
# [180]	train-mlogloss:0.18005	eval-mlogloss:0.57324
# [181]	train-mlogloss:0.17908	eval-mlogloss:0.57318
# [182]	train-mlogloss:0.17800	eval-mlogloss:0.57313
# [183]	train-mlogloss:0.17704	eval-mlogloss:0.57342
# [184]	train-mlogloss:0.17624	eval-mlogloss:0.57339
# [185]	train-mlogloss:0.17552	eval-mlogloss:0.57342
# [186]	train-mlogloss:0.17451	eval-mlogloss:0.57346
# [187]	train-mlogloss:0.17380	eval-mlogloss:0.57350
# [188]	train-mlogloss:0.17257	eval-mlogloss:0.57359
# [189]	train-mlogloss:0.17170	eval-mlogloss:0.57365
# [190]	train-mlogloss:0.17051	eval-mlogloss:0.57387
# [191]	train-mlogloss:0.16957	eval-mlogloss:0.57374
# [192]	train-mlogloss:0.16846	eval-mlogloss:0.57377
# [193]	train-mlogloss:0.16753	eval-mlogloss:0.57400
# [194]	train-mlogloss:0.16657	eval-mlogloss:0.57384
# [195]	train-mlogloss:0.16588	eval-mlogloss:0.57369
# [196]	train-mlogloss:0.16494	eval-mlogloss:0.57405
# [197]	train-mlogloss:0.16406	eval-mlogloss:0.57404
# [198]	train-mlogloss:0.16320	eval-mlogloss:0.57408
# [199]	train-mlogloss:0.16226	eval-mlogloss:0.57425
# [200]	train-mlogloss:0.16133	eval-mlogloss:0.57454
# [201]	train-mlogloss:0.16047	eval-mlogloss:0.57470
# [202]	train-mlogloss:0.15953	eval-mlogloss:0.57472
# [203]	train-mlogloss:0.15870	eval-mlogloss:0.57468
# [204]	train-mlogloss:0.15802	eval-mlogloss:0.57499
# [205]	train-mlogloss:0.15731	eval-mlogloss:0.57484
# [206]	train-mlogloss:0.15634	eval-mlogloss:0.57497
# [207]	train-mlogloss:0.15545	eval-mlogloss:0.57519
# [208]	train-mlogloss:0.15466	eval-mlogloss:0.57520
# [209]	train-mlogloss:0.15379	eval-mlogloss:0.57526
# [210]	train-mlogloss:0.15313	eval-mlogloss:0.57545
# [211]	train-mlogloss:0.15230	eval-mlogloss:0.57521
# [212]	train-mlogloss:0.15145	eval-mlogloss:0.57515
# [213]	train-mlogloss:0.15062	eval-mlogloss:0.57538
# [214]	train-mlogloss:0.15006	eval-mlogloss:0.57532
# [215]	train-mlogloss:0.14923	eval-mlogloss:0.57544
# [216]	train-mlogloss:0.14846	eval-mlogloss:0.57551
# [217]	train-mlogloss:0.14781	eval-mlogloss:0.57560
# [218]	train-mlogloss:0.14688	eval-mlogloss:0.57588
# [219]	train-mlogloss:0.14614	eval-mlogloss:0.57599
# [220]	train-mlogloss:0.14547	eval-mlogloss:0.57600
# [221]	train-mlogloss:0.14453	eval-mlogloss:0.57606
# [222]	train-mlogloss:0.14388	eval-mlogloss:0.57611
# [223]	train-mlogloss:0.14311	eval-mlogloss:0.57617
# [224]	train-mlogloss:0.14252	eval-mlogloss:0.57624
# [225]	train-mlogloss:0.14181	eval-mlogloss:0.57641
# [226]	train-mlogloss:0.14082	eval-mlogloss:0.57648
# [227]	train-mlogloss:0.13996	eval-mlogloss:0.57660
# [228]	train-mlogloss:0.13920	eval-mlogloss:0.57668
# [229]	train-mlogloss:0.13846	eval-mlogloss:0.57670
# [230]	train-mlogloss:0.13758	eval-mlogloss:0.57697
# [231]	train-mlogloss:0.13703	eval-mlogloss:0.57707
# [232]	train-mlogloss:0.13652	eval-mlogloss:0.57715
# [233]	train-mlogloss:0.13572	eval-mlogloss:0.57756
# [234]	train-mlogloss:0.13512	eval-mlogloss:0.57730
# [235]	train-mlogloss:0.13441	eval-mlogloss:0.57733

# %% [markdown]
# ### Some analysis

# %%
xgb.plot_importance(bst, max_num_features=25)
fig = plt.gcf()
fig.set_size_inches(15, 20)

# %% [markdown]
# ### Accuracy on test set

# %% [markdown]
# A simple benchmark is always predicting home wins

# %%
target = train_scores.loc[X_test.index].copy()

home_wins = target
home_wins = 0 * home_wins
home_wins.iloc[:,0] = 1

np.round(accuracy_score(home_wins,target),4)
# Out:
# 0.4401

# %% [markdown]
# Using our model

# %%
X_test_xgb = xgb.DMatrix(X_test)

predictions = bst.predict(X_test_xgb, iteration_range=(0, bst.best_iteration))
predictions = pd.DataFrame(predictions)

predictions[2] = 0
predictions.columns = [0,2,1]
predictions = (predictions.reindex(columns=[0,1,2]).rank(1,ascending=False)==1).astype(int).values
np.round(accuracy_score(predictions,target),4)
# Out:
# 0.475

# %% [markdown]
# ## Submission

# %%
test_home = pd.read_csv('./datas_final/test_home_team_statistics_df.csv', index_col=0)
test_away = pd.read_csv('./datas_final/test_away_team_statistics_df.csv', index_col=0)

test_home.columns = 'HOME_' + test_home.columns
test_away.columns = 'AWAY_' + test_away.columns

test_data =  pd.concat([test_home,test_away],join='inner',axis=1)

# %%
X_bench = xgb.DMatrix(test_data)

predictions = bst.predict(X_bench, iteration_range=(0, bst.best_iteration))
predictions = pd.DataFrame(predictions)

predictions[2] = 0
predictions.columns = [0,2,1]
predictions = (predictions.reindex(columns=[0,1,2]).rank(1,ascending=False)==1).astype(int)

predictions.columns = ['HOME_WINS', 'DRAW', 'AWAY_WINS']
predictions.index = test_data.index
submission = predictions.reset_index()
submission.to_csv('./datas_final/benchmark_submission.csv', index=False)
